# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import utils
#
# File ~/Code/groupfinding_comparisons/src/groupfinder_comparison/utils.py:87
#      80         raise ValueError("Could not find galaxy ID column in Sharks data.")
#      82     return df
#      84 def load_membership_with_optional_gama_mapping(
#      85     file: str,
#      86     output_group_name: str,
# ---> 87     gama_id_mapping_file: str | None = None,
#      88 ) -> pd.DataFrame:
#      89     df = read_table(file)
#      91     # If this is a GAMA-style membership table with CATAID rather than uberID,
#      92     # convert to uberID using the supplied mapping.
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'

# %%
gama, nessie_groups, sussex_groups, bij = utils.load_group_set_gama()

print(gama.head())
print("Nessie groups:", len(nessie_groups))
print("Sussex groups:", len(sussex_groups))
print("Number of bijective matches:", len(bij[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gama, nessie_groups, sussex_groups, bij = utils.load_group_set_gama()
#       3 print(gama.head())
#       4 print("Nessie groups:", len(nessie_groups))
#
# File ~/Code/groupfinding_comparisons/src/groupfinder_comparison/utils.py:200, in load_group_set_gama(gama_file, nessie_members_file, sussex_members_file, nessie_groups_file, sussex_groups_file, gama_id_mapping_file)
#     190 def load_group_set_gama(
#     191     gama_file: str = "/Users/sp624AA/Downloads/gama3/groupfinding_gama4_processed.parquet",
#     192     nessie_members_file: str = "/Users/sp624AA/Downloads/gama3/G3CGalv10.fits",
#    (...)    196     gama_id_mapping_file: str = "/Users/sp624AA/Downloads/gama3/gkvGamaIIMatchesv01.fits",
#     197 ):
#     198     gama = load_gama_data(gama_file).copy()
# ...
